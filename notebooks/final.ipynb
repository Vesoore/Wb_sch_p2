# %%
import pandas as pd

# %%
cd ..
# Out:
# /Users/aleksandr/Wb_sch_p2/Wb_sch_p2
# /Users/aleksandr/Library/Caches/pypoetry/virtualenvs/wb-sch-p2-7_DfuszP-py3.11/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
neg = pd.read_csv('data/train_neg.csv')
pos = pd.read_csv('data/train_pos.csv')

# %%
for index, row in neg.iterrows():
    print(index, row['Question'], '===', row['Answer'])
# Out:
# 0 когда появится в продаже? === Вопрос к WB
# 1 Здравствуйте, а когда bb крем появится в наличии? === Вопрос к WB
# 2 здравствуйте, когда снова появится на складе? === Вопрос к WB
# 3 Здравствуйте! когда появится в наличии оттенок 613? === Добрый день! Благодарим за обращение и внимание к продукции бренда L`Oreal Paris.  Оттенок 613 Морозное глясе не снят с производства - это темно-русый оттенок с пепельным подтоном и розовыми переливами. Добавляйте продукт в избранное, чтобы следить пополнением ассортимента. Возможно, Вас заинтересует краска для волос без аммиака Excellence Nudes в оттенке 6U (Артикул: 155771439), которая также не имеет аммиака в составе. Русая база с тройным подтоном: пепельным, перламутровым и золотистым. Хорошего дня!
# 4 когда появится в наличии? === Здравствуйте! Благодарим за обращение. Крем-пенка есть в наличии.
# 5 Когда появится в наличии ?) === Здравствуйте! Благодарим за обращение. Данный товар есть в наличии.
# ...
