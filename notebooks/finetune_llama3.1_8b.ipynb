# %%
import pandas as pd

# %%
train_pos = pd.read_csv('train_pos.csv')
train_neg = pd.read_csv('train_neg.csv')

# %%
data = pd.concat([train_pos, train_neg])

# %%
data
# Out:
#            NmId                                           Question  \
# 0     218981489  Здравствуйте. Подскажите пожалуйста в чем разн...
# 1       5110298  По какой таблице размеров выбирать размер на ф...
# 2       2941241                 не знаю какую выбрать(((доче 9 лет
# 3       4107067  Здравствуйте! У меня вопрос по вашему товару Б...
# 4       5970810          Какой состав материала и чьё производство
# ...         ...                                                ...
# 1567    5163995  Здравствуйте, робот-пылесос обезумел: ездит ры...
# 1568    5163995  В начале пылесос работал нормально потом стал ...
# 1569   31211424  Добрый день! Хотела бы поинтересоваться, почем...
# 1570   31211424  Купили сегодня, установили приложение.. Он не ...
# 1571   31211424                    не был оплачен обещанный кешбек
#
#                                             Description  \
# 0     {'Цвет': 'бежевый', 'Высота упаковки': '51 см'...
# ...

# %%
data['desc'] = data.apply(lambda x: x.desk if len(x.desk) < 200 else x.desk[:200], axis=1)

# %%
dataset = pd.DataFrame(columns=['Instruction', 'Input', 'Response'])

# %%
dataset['Input'] = data['Question'] + '\n' + data['desc']
dataset['Response'] = data['label']
dataset['Instruction'] = """
You are a moderator of questions on the marketplace.
You receive a customer's question and its description as input.
Your task is to evaluate whether the question is related to the characteristics of the product,
its capabilities, configuration, etc. or not.
If the input data contains a question about the delivery date, delivery delay, product defect,
promotions, discounts, product prices, refunds, the ability to buy, etc.,
or does not contain a question about the product at all, then
you need to output 0 .
If the question concerns its characteristics, size chart, material, capabilities and configuration of the product, etc.,
then you need to output 1.
The answer must contain one number - 0 or 1.
"""

# %%
dataset
# Out:
#                                             Instruction  \
# 0     \nYou are a moderator of questions on the mark...
# 1     \nYou are a moderator of questions on the mark...
# 2     \nYou are a moderator of questions on the mark...
# 3     \nYou are a moderator of questions on the mark...
# 4     \nYou are a moderator of questions on the mark...
# ...                                                 ...
# 1567  \nYou are a moderator of questions on the mark...
# 1568  \nYou are a moderator of questions on the mark...
# 1569  \nYou are a moderator of questions on the mark...
# 1570  \nYou are a moderator of questions on the mark...
# 1571  \nYou are a moderator of questions on the mark...
#
#                                                   Input  Response
# 0     Здравствуйте. Подскажите пожалуйста в чем разн...         1
# 1     По какой таблице размеров выбирать размер на ф...         1
# 2     не знаю какую выбрать(((доче 9 лет\nПодушка де...         1
# ...

# %%
# !pip install datasets

# %%
from datasets import Dataset
dataset = Dataset.from_pandas(dataset)

# %%
dataset = dataset.shuffle(42)

# %%
# !pip install unsloth
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# ...
# Found existing installation: unsloth 2024.11.10
# Uninstalling unsloth-2024.11.10:
#   Successfully uninstalled unsloth-2024.11.10
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-7e_7gd_n/unsloth_7091ff863aed4c4fa8eee39f00d31809
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-7e_7gd_n/unsloth_7091ff863aed4c4fa8eee39f00d31809
#   Resolved https://github.com/unslothai/unsloth.git to commit 8558bc92b06f9128499484ef737fa71b966ffc23
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for unsloth: filename=unsloth-2024.11.10-py3-none-any.whl size=166794 sha256=632478b4e4d912ad9d510d2d59fc6cbcddbae2ca4c189c7f2f41f1a7645d08b2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5sa89r0z/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# ...

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None # None for auto detection.
load_in_4bit = True # Use 4bit quantization to reduce memory usage.


model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit, #qlora
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2024.11.10: Fast Llama patching. Transformers:4.46.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 7.5. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)
# Out:
# Unsloth 2024.11.10 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    instructions = examples["Instruction"]
    inputs       = examples["Input"]
    outputs      = examples["Response"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass


dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Map:   0%|          | 0/2512 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['Instruction', 'Input', 'Response', '__index_level_0__', 'text'],
#     num_rows: 2512
# })

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False,
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        num_train_epochs = 2, # Set this for 1 full training run.
        # max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to="wandb"
    ),
)
# Out:
# Map (num_proc=2):   0%|          | 0/2512 [00:00<?, ? examples/s]

# %%
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 6.004 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 2,512 | Num Epochs = 2
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 628
#  "-____-"     Number of trainable parameters = 41,943,040
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: hvizze (misis_edu). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241126_183628-6im9ij3q</code>
# ...

# %%
hf_token = "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"
hf_username = "Hvixze"

# %%
model.push_to_hub(f"{hf_username}/wb_llama3_2ep_sec", token = hf_token) # Online saving
tokenizer.push_to_hub(f"{hf_username}/wb_llama3_2ep_sec", token = hf_token)
# Out:
# README.md:   0%|          | 0.00/587 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/168M [00:00<?, ?B/s]
# Saved model to https://huggingface.co/Hvixze/wb_llama3_2ep_sec
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]

# %%
val_neg = pd.read_csv('valid_250_neg.csv')
val_pos = pd.read_csv('valid_250_pos.csv')

# %%
val = pd.concat([val_neg, val_pos])

# %%
val
# Out:
#           NmId                                           Question  \
# 0      3311681  Добрый день, поступления примерно когда будут ...
# 1      4985322  4985322 здравствуйте. когда будет в наличии эт...
# 2      4271926  Ничего он не удаляет,абсолютно! Написала отзыв...
# 3      2025403  Я в шоке, испортила волосы, всё время крашу св...
# 4      2392593  Здравствуйте,возможно-ли использование  для гл...
# ..         ...                                                ...
# 245  221737249  Добрый день. Подскажите, пожалуйста, правильно...
# 246    5764902  Здравствуйте, подскажите, какой размер выбрать...
# 247  238503646  Подскажите, пожалуйста, как убрать вкрапления ...
# 248  165904339              Здравствуйте, подойдёт ли к ноутбуку?
# 249   71350107  добрый день подскажите пожалуйста моя дочка се...
#
#                                            Description  \
# 0    {'Вес товара с упаковкой (г)': '340 г', 'Высот...
# 1    {'Покрой': 'классический', 'Назначение': 'выпу...
# ...

# %%
val['desc'] = val.apply(lambda x: x.desk if len(x.desk) < 200 else x.desk[:200], axis=1)

# %%
instruction = """
You are a moderator of questions on the marketplace.
You receive a customer's question and its description as input.
Your task is to evaluate whether the question is related to the characteristics of the product,
its capabilities, configuration, etc. or not.
If the input data contains a question about the delivery date, delivery delay, product defect,
promotions, discounts, product prices, refunds, the ability to buy, etc.,
or does not contain a question about the product at all, then
you need to output 0 .
If the question concerns its characteristics, size chart, material, capabilities and configuration of the product, etc.,
then you need to output 1.
The answer must contain one number - 0 or 1.
"""

alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

# %%
import re
def predict(row: pd.Series):


    FastLanguageModel.for_inference(model)

    prompt_string = alpaca_prompt.format(
    instruction,
    row["Question"] + "/n" + row["desc"],
    ""
)
    inputs = tokenizer(
        [prompt_string],
        return_tensors="pt"
    ).to("cuda")

    outputs = model.generate(**inputs, max_new_tokens = 128, use_cache = True)
    decode = tokenizer.batch_decode(outputs)
    match = re.search(r'### Response:\n(.*?)(?=<\|end_of_text\|>)', decode[0], re.DOTALL)
    if match is not None:
        response = match.group(1).strip()
        return response
    else:
        return "undefined"

# %%
val['pred'] = val.apply(lambda x: predict(x), axis=1)

# %%
val['pred'] = val['pred'].astype(int)

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
precision_score(val['label'], val['pred']), recall_score(val['label'], val['pred'])
# Out:
# (0.8764478764478765, 0.908)

# %%
val[(val.pred == 1) & (val.label == 0)]
# Out:
#           NmId                                           Question  \
# 4      2392593  Здравствуйте,возможно-ли использование  для гл...
# 10   116563734  здравствуйте, почему она не реагирует при движ...
# 32     5970810  Добрый день, подскажите пожалуйста, какой разм...
# 39    90223984  Здравствуйте! Покупаем данный костюм уже 4 год...
# 50    54087264  Здравствуйте! Можно купить только две наволочк...
# 55     4945730  От сети работает, если вдруг батарейки сели, с...
# 56     5005397  Здравствуйте.  ОГ 88, ОТ 74, ОБ 98  какой  раз...
# 65     3867348  Здравствуйте! 23/6 на какой российский размер ...
# 77   154768478  Добрый день! Подскажите, пожалуйста, какой нео...
# 79     4945730                  Адаптер питания в комплекте есть?
# 91    54087264  здравствуйте. почему у вас нет постельного бел...
# 96     3671810  Здравствуйте! А есть джибитсы на маленькие кро...
# 104    4000411  Добрый день. Планирую заказать обручальное кол...
# ...

# %%
hf_token = ""
hf_username = "Hvixze"
model.push_to_hub(f"{hf_username}/wb_llama3_2ep_first", token = hf_token) # Online saving
tokenizer.push_to_hub(f"{hf_username}/wb_llama3_2ep_first", token = hf_token)
